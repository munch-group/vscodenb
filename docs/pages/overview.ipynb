# %% [raw]
# ---
# title: Overview
# aliases:
#   - ../index.html
# jupyter:
#   kernelspec:
#     display_name: Python 3 (ipykernel)
#     language: python
#     name: python3
# ---

# %% [markdown]
# **vsnb** lets you ...
#
# {{< lipsum 1 >}}
#
# ## Installation
#
# ::: {.panel-tabset}
#
# ## Pixi
#
# ```bash
# pixi workspace channel add munch-group
# pixi add vsnb
# ```
#
# ## conda
#
# ```bash
# conda install -c munch-group vsnb
# ```
#
# ## Pip
#
# ```bash
# pip install vsnb
# ```
#
# :::

# %% [markdown]
# ## Basic use

# %%
from vsnb import set_vscode_theme, cpu_monitor, pqdm, prange

set_vscode_theme()

# %%
# %%cpu_monitor
#
# time.sleep(3)

# %%
import time

for i in prange(10):
    for i in prange(10):
        time.sleep(0.1)
