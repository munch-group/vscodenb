# %% [raw]
# ---
# title: CPU monitoring
# ---

# %%
import vscodenb # importing automatically registers the ipython magic
import multiprocess as mp

def work(cpus=mp.cpu_count()):
    def f(x):
        return sum(range(x * 100_000_000))
    with mp.Pool(cpus) as p:
        p.map(f, [1] * 2 * cpus)

# %% [markdown]
# ## Magic: For cells
#
# The `%%monitor` cell magic lets you monitor CPU and memory usage as a cell runs. Just add it at the top of any cell.

# %%
# %%monitor
#
# work()

# %% [markdown]
# Use `--persist` or `-p` if you want the widget to persist after cell execution completes. This can be useful as a reminder of CPU/memory used:

# %%
# %%monitor -p
#
# work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(39%/40% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 98.7% avg">
#                             <div style="width: 98.6888888888889%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 98.9% avg">
#                             <div style="width: 98.88888888888889%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 98.7% avg">
#                             <div style="width: 98.6888888888889%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 98.2% avg">
#                             <div style="width: 98.19999999999999%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 97.6% avg">
#                             <div style="width: 97.6%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 97.7% avg">
#                             <div style="width: 97.74444444444445%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 97.4% avg">
#                             <div style="width: 97.37777777777778%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 97.1% avg">
#                             <div style="width: 97.14444444444445%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>

# %% [markdown]
# Increase update frequency for smoother visualization use four updates per second:

# %%
# %%monitor -p -i 0.25
#
# work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(38%/39% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 98.2% avg">
#                             <div style="width: 98.23333333333333%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 98.2% avg">
#                             <div style="width: 98.23333333333333%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 98.2% avg">
#                             <div style="width: 98.23888888888888%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 97.6% avg">
#                             <div style="width: 97.56666666666666%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 96.7% avg">
#                             <div style="width: 96.70555555555556%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 96.6% avg">
#                             <div style="width: 96.58333333333333%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 96.2% avg">
#                             <div style="width: 96.22222222222223%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 96.9% avg">
#                             <div style="width: 96.88888888888889%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>

# %%
# %%monitor -p -c
#
# work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(37%/38% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 98.0% avg">
#                             <div style="width: 98.03333333333333%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 97.8% avg">
#                             <div style="width: 97.82222222222222%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 97.8% avg">
#                             <div style="width: 97.82222222222222%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 97.1% avg">
#                             <div style="width: 97.11111111111111%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 95.3% avg">
#                             <div style="width: 95.28888888888889%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 94.6% avg">
#                             <div style="width: 94.55555555555556%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 94.5% avg">
#                             <div style="width: 94.54444444444444%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 93.7% avg">
#                             <div style="width: 93.67777777777778%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#                         </div></div></div>

# %% [markdown]
# Produce summary percentages instead of gauges (overrides `-p`):

# %%
# %%monitor -s
#
# work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 12px;"><div style="margin-bottom: 8px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(37%/38% mem)</span></div><table style="border-collapse: collapse; width: 100%;"><tr style="background-color: rgba(128, 128, 128, 0.1);"><td style="padding: 4px 8px; font-weight: bold;">CPU %</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">96</td><td style="padding: 4px 8px; text-align: center;">96</td><td style="padding: 4px 8px; text-align: center;">95</td><td style="padding: 4px 8px; text-align: center;">96</td></tr></table><div style="margin-top: 6px; font-size: 11px;">Total CPU time: <span style="font-weight: normal; color: #666;">31.38 s</span></div></div></div>

# %% [markdown]
# Widget fills width of cell by default. To limit width, use -w option:

# %%
# %%monitor -p -w 100
#
# work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px; max-width: 100ch;"><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(36%/36% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 97.8% avg">
#                             <div style="width: 97.82222222222222%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 97.8% avg">
#                             <div style="width: 97.82222222222222%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 97.6% avg">
#                             <div style="width: 97.6%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 96.6% avg">
#                             <div style="width: 96.62222222222222%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 93.9% avg">
#                             <div style="width: 93.9%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 94.2% avg">
#                             <div style="width: 94.22222222222223%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 93.0% avg">
#                             <div style="width: 93.02222222222223%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 93.6% avg">
#                             <div style="width: 93.55555555555556%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>

# %% [markdown]
# You can also override the automatic computation of CPU gauges per line:

# %%
# %%monitor -p -f 4 -w 50
#
# work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px; max-width: 50ch;"><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(35%/36% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 97.3% avg">
#                             <div style="width: 97.33333333333333%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 97.4% avg">
#                             <div style="width: 97.38888888888889%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 97.1% avg">
#                             <div style="width: 97.11111111111111%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 96.1% avg">
#                             <div style="width: 96.07777777777778%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 93.0% avg">
#                             <div style="width: 93.03333333333333%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 93.2% avg">
#                             <div style="width: 93.16666666666667%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 92.4% avg">
#                             <div style="width: 92.36666666666666%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 9px) / 4); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 92.6% avg">
#                             <div style="width: 92.58888888888889%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>

# %% [markdown]
# ## Context Manager: For scripts or parts of cells
#
# The context manager gives you explicit control over monitoring.
# Perfect for Python scripts or when you want programmatic control.
#
# ### Basic Context Manager

# %%
from vscodenb import CPUMonitor

with CPUMonitor(label="Computation Phase", persist=True, color=True):
    work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">Computation Phase</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(35%/36% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 98.8% avg">
#                             <div style="width: 98.8%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 98.6% avg">
#                             <div style="width: 98.62%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 98.6% avg">
#                             <div style="width: 98.6%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 98.6% avg">
#                             <div style="width: 98.61%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 90.8% avg">
#                             <div style="width: 90.77000000000001%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 89.8% avg">
#                             <div style="width: 89.82000000000001%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 90.8% avg">
#                             <div style="width: 90.78%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 91.2% avg">
#                             <div style="width: 91.17%; height: 100%; background: #4CAF50;"></div>
#                         </div>
#                         </div></div></div>

# %% [markdown]
# All arguments to the `monitor` magic can also be passed to `CPUMonitor`:

# %%
with CPUMonitor(summary=True, label="First computation"):
    work()

with CPUMonitor(summary=True, label="Second computation"):
    work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">First computation</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 8px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(34%/35% mem)</span></div><table style="border-collapse: collapse; width: 100%;"><tr style="background-color: rgba(128, 128, 128, 0.1);"><td style="padding: 4px 8px; font-weight: bold;">CPU %</td><td style="padding: 4px 8px; text-align: center;">97</td><td style="padding: 4px 8px; text-align: center;">97</td><td style="padding: 4px 8px; text-align: center;">97</td><td style="padding: 4px 8px; text-align: center;">95</td><td style="padding: 4px 8px; text-align: center;">92</td><td style="padding: 4px 8px; text-align: center;">91</td><td style="padding: 4px 8px; text-align: center;">90</td><td style="padding: 4px 8px; text-align: center;">90</td></tr></table><div style="margin-top: 6px; font-size: 11px;">Total CPU time: <span style="font-weight: normal; color: #666;">33.94 s</span></div></div></div>
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">Second computation</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 8px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(34%/35% mem)</span></div><table style="border-collapse: collapse; width: 100%;"><tr style="background-color: rgba(128, 128, 128, 0.1);"><td style="padding: 4px 8px; font-weight: bold;">CPU %</td><td style="padding: 4px 8px; text-align: center;">99</td><td style="padding: 4px 8px; text-align: center;">99</td><td style="padding: 4px 8px; text-align: center;">99</td><td style="padding: 4px 8px; text-align: center;">99</td><td style="padding: 4px 8px; text-align: center;">92</td><td style="padding: 4px 8px; text-align: center;">91</td><td style="padding: 4px 8px; text-align: center;">91</td><td style="padding: 4px 8px; text-align: center;">90</td></tr></table><div style="margin-top: 6px; font-size: 11px;">Total CPU time: <span style="font-weight: normal; color: #666;">34.79 s</span></div></div></div>

# %% [markdown]
# ## Decorator: For functions
#
# Wrap any function with `@monitor` to automatically monitor its execution. The decorator takes the same arguments as the magic and the context manager, but here the label defaults to the function name.

# %%
from vscodenb import monitor

@monitor
def some_function():
    work()

@monitor
def other_function():
    work()

# %% [markdown]
# That lets you track CPU usage for your code in real time:

# %%
for _ in range(3):
    some_function()
other_function()

# %%
@monitor(persist=True)
def some_function():
    work()

for _ in range(3):
    some_function()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">some_function</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(33%/34% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 97.8% avg">
#                             <div style="width: 97.76%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 97.4% avg">
#                             <div style="width: 97.4%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 97.2% avg">
#                             <div style="width: 97.21000000000001%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 96.2% avg">
#                             <div style="width: 96.2%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 96.7% avg">
#                             <div style="width: 96.67%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 94.0% avg">
#                             <div style="width: 94.0%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 92.9% avg">
#                             <div style="width: 92.94%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 93.4% avg">
#                             <div style="width: 93.41%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">some_function</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(35%/35% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 96.8% avg">
#                             <div style="width: 96.8%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 96.7% avg">
#                             <div style="width: 96.67%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 95.3% avg">
#                             <div style="width: 95.28999999999999%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 94.8% avg">
#                             <div style="width: 94.8%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 96.3% avg">
#                             <div style="width: 96.27000000000001%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 96.7% avg">
#                             <div style="width: 96.72999999999999%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 96.2% avg">
#                             <div style="width: 96.2%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 93.3% avg">
#                             <div style="width: 93.33%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">some_function</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(34%/35% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 98.9% avg">
#                             <div style="width: 98.88888888888889%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 98.9% avg">
#                             <div style="width: 98.91111111111111%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 98.7% avg">
#                             <div style="width: 98.6888888888889%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 98.3% avg">
#                             <div style="width: 98.25555555555555%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 97.6% avg">
#                             <div style="width: 97.6%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 97.8% avg">
#                             <div style="width: 97.77777777777777%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 97.6% avg">
#                             <div style="width: 97.55555555555556%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 21px) / 8); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 96.9% avg">
#                             <div style="width: 96.94444444444444%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>

# %% [markdown]
# Or profile them using `summary=True`:

# %%
@monitor(summary=True)
def some_function():
    work()

@monitor(summary=True)
def other_function():
    work()

# %%
some_function()   
other_function()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">some_function</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 8px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(34%/34% mem)</span></div><table style="border-collapse: collapse; width: 100%;"><tr style="background-color: rgba(128, 128, 128, 0.1);"><td style="padding: 4px 8px; font-weight: bold;">CPU %</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">97</td><td style="padding: 4px 8px; text-align: center;">96</td><td style="padding: 4px 8px; text-align: center;">97</td><td style="padding: 4px 8px; text-align: center;">96</td><td style="padding: 4px 8px; text-align: center;">97</td><td style="padding: 4px 8px; text-align: center;">97</td></tr></table><div style="margin-top: 6px; font-size: 11px;">Total CPU time: <span style="font-weight: normal; color: #666;">31.37 s</span></div></div></div>
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">other_function</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 8px; font-size: 11px;">Francis <span style="font-weight: normal; color: #666;">(35%/35% mem)</span></div><table style="border-collapse: collapse; width: 100%;"><tr style="background-color: rgba(128, 128, 128, 0.1);"><td style="padding: 4px 8px; font-weight: bold;">CPU %</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">97</td><td style="padding: 4px 8px; text-align: center;">97</td><td style="padding: 4px 8px; text-align: center;">97</td><td style="padding: 4px 8px; text-align: center;">97</td></tr></table><div style="margin-top: 6px; font-size: 11px;">Total CPU time: <span style="font-weight: normal; color: #666;">31.58 s</span></div></div></div>
