# %% [raw]
# ---
# title: CPU monitoring
# ---

# %%
import vsnb # importing vsnb automacally registers the ipytho magic
import multiprocess as mp

def work(cpus=mp.cpu_count()):
    def f(x):
        return sum(range(x * 100_000_000))
    with mp.Pool(cpus) as p:
        p.map(f, [1] * 2 * cpus)

# %% [markdown]
# ## Magic: For cells
#
# The `%%monitor` cell magic lets you monitor CPU and memory usage as a cell runs. Just add it at the top of any cell.

# %%
# %%monitor
#
# work()

# %% [markdown]
# Use `--persist` or `-p` if you want the widget to persist after cell execution completes. This can be useful as a reminder of CPU/memory used:

# %%
# %%monitor -p
#
# work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 12px;"><div style="margin-bottom: 6px; font-size: 11px;">macbookpro <span style="font-weight: normal; color: #666;">(37%/38% mem)</span></div><div style="display: flex; gap: 3px; width: 100%; margin-bottom: 3px;">
#                         <div style="width: calc((100% - 27px) / 10); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 0: 99.2% avg">
#                             <div style="width: 99.15714285714286%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 27px) / 10); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 1: 98.9% avg">
#                             <div style="width: 98.88571428571429%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 27px) / 10); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 2: 97.7% avg">
#                             <div style="width: 97.71428571428571%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 27px) / 10); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 3: 97.5% avg">
#                             <div style="width: 97.5%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 27px) / 10); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 4: 97.5% avg">
#                             <div style="width: 97.47142857142856%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 27px) / 10); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 5: 97.2% avg">
#                             <div style="width: 97.15714285714286%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 27px) / 10); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 6: 97.0% avg">
#                             <div style="width: 96.97142857142858%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 27px) / 10); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 7: 96.9% avg">
#                             <div style="width: 96.89999999999999%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 27px) / 10); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 8: 96.4% avg">
#                             <div style="width: 96.41428571428571%; height: 100%; background: #666666;"></div>
#                         </div>
#
#                         <div style="width: calc((100% - 27px) / 10); min-width: 20px; height: 8px; background: rgba(128, 128, 128, 0.2); border-radius: 2px; overflow: hidden;" title="CPU 9: 95.9% avg">
#                             <div style="width: 95.94285714285715%; height: 100%; background: #666666;"></div>
#                         </div>
#                         </div></div></div>

# %% [markdown]
# Increase update frequency for smoother visualization use four updates per second:

# %%
# %%monitor -i 0.25
#
# work()

# %%
# %%monitor -c
#
# work()

# %% [markdown]
# Produce summary percentages instead of gauges (overrides `-p`):

# %%
# %%monitor -s
#
# work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 12px;"><div style="margin-bottom: 8px; font-size: 11px;">macbookpro <span style="font-weight: normal; color: #666;">(37%/37% mem)</span></div><table style="border-collapse: collapse; width: 100%;"><tr style="background-color: rgba(128, 128, 128, 0.1);"><td style="padding: 4px 8px; font-weight: bold;">CPU %</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">99</td><td style="padding: 4px 8px; text-align: center;">89</td><td style="padding: 4px 8px; text-align: center;">88</td><td style="padding: 4px 8px; text-align: center;">86</td><td style="padding: 4px 8px; text-align: center;">85</td><td style="padding: 4px 8px; text-align: center;">86</td><td style="padding: 4px 8px; text-align: center;">84</td><td style="padding: 4px 8px; text-align: center;">84</td><td style="padding: 4px 8px; text-align: center;">84</td></tr></table><div style="margin-top: 6px; font-size: 11px;">Total CPU time: <span style="font-weight: normal; color: #666;">31.12 s</span></div></div></div>

# %% [markdown]
# Override automatic computation of gauges per line:

# %%
# %%monitor -f 2
#
# work()

# %% [markdown]
# ## Context Manager: For scripts or parts of cells
#
# The context manager gives you explicit control over monitoring.
# Perfect for Python scripts or when you want programmatic control.
#
# ### Basic Context Manager

# %%
from vsnb import CPUMonitor

with CPUMonitor(label="Computation Phase", color=True):
    work()

# %% [markdown]
# All arguments to the `monitor` magic can also be passed to `CPUMonitor`:

# %%
with CPUMonitor(summary=True, label="First computation"):
    work()

with CPUMonitor(summary=True, label="Second computation"):
    work()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">First computation</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 8px; font-size: 11px;">macbookpro <span style="font-weight: normal; color: #666;">(38%/38% mem)</span></div><table style="border-collapse: collapse; width: 100%;"><tr style="background-color: rgba(128, 128, 128, 0.1);"><td style="padding: 4px 8px; font-weight: bold;">CPU %</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">96</td><td style="padding: 4px 8px; text-align: center;">97</td><td style="padding: 4px 8px; text-align: center;">96</td><td style="padding: 4px 8px; text-align: center;">95</td><td style="padding: 4px 8px; text-align: center;">95</td><td style="padding: 4px 8px; text-align: center;">94</td><td style="padding: 4px 8px; text-align: center;">93</td><td style="padding: 4px 8px; text-align: center;">93</td></tr></table><div style="margin-top: 6px; font-size: 11px;">Total CPU time: <span style="font-weight: normal; color: #666;">33.90 s</span></div></div></div>
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">Second computation</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 8px; font-size: 11px;">macbookpro <span style="font-weight: normal; color: #666;">(37%/38% mem)</span></div><table style="border-collapse: collapse; width: 100%;"><tr style="background-color: rgba(128, 128, 128, 0.1);"><td style="padding: 4px 8px; font-weight: bold;">CPU %</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">98</td><td style="padding: 4px 8px; text-align: center;">97</td><td style="padding: 4px 8px; text-align: center;">97</td><td style="padding: 4px 8px; text-align: center;">97</td><td style="padding: 4px 8px; text-align: center;">96</td><td style="padding: 4px 8px; text-align: center;">96</td><td style="padding: 4px 8px; text-align: center;">95</td><td style="padding: 4px 8px; text-align: center;">95</td><td style="padding: 4px 8px; text-align: center;">95</td></tr></table><div style="margin-top: 6px; font-size: 11px;">Total CPU time: <span style="font-weight: normal; color: #666;">29.11 s</span></div></div></div>

# %% [markdown]
# ## Decorator: For functions
#
# Wrap any function with `@monitor` to automatically monitor its execution. The decorator takes the same arguments as the magic and the context manager, but here the label defaults to the function name.

# %%
from vsnb import monitor

@monitor
def some_function():
    work()

@monitor
def other_function():
    work()

# %% [markdown]
# That lets you track CPU usage for your code in real time:

# %%
for _ in range(3):
    some_function()
other_function()

# %% [markdown]
# Or profile them using `summary=True`:

# %%
@monitor(summary=True)
def some_function():
    work()

@monitor(summary=True)
def other_function():
    work()

# %%
some_function()   
other_function()
# Out:
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">some_function</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 8px; font-size: 11px;">macbookpro <span style="font-weight: normal; color: #666;">(38%/38% mem)</span></div><table style="border-collapse: collapse; width: 100%;"><tr style="background-color: rgba(128, 128, 128, 0.1);"><td style="padding: 4px 8px; font-weight: bold;">CPU %</td><td style="padding: 4px 8px; text-align: center;">91</td><td style="padding: 4px 8px; text-align: center;">91</td><td style="padding: 4px 8px; text-align: center;">89</td><td style="padding: 4px 8px; text-align: center;">90</td><td style="padding: 4px 8px; text-align: center;">88</td><td style="padding: 4px 8px; text-align: center;">88</td><td style="padding: 4px 8px; text-align: center;">88</td><td style="padding: 4px 8px; text-align: center;">88</td><td style="padding: 4px 8px; text-align: center;">88</td><td style="padding: 4px 8px; text-align: center;">88</td></tr></table><div style="margin-top: 6px; font-size: 11px;">Total CPU time: <span style="font-weight: normal; color: #666;">31.47 s</span></div></div></div>
# <div style="font-family: monospace; font-size: 10px; padding: 10px;"><div style="margin-bottom: 8px; font-weight: bold; font-size: 12px;">other_function</div><div style="margin-bottom: 12px;"><div style="margin-bottom: 8px; font-size: 11px;">macbookpro <span style="font-weight: normal; color: #666;">(38%/38% mem)</span></div><table style="border-collapse: collapse; width: 100%;"><tr style="background-color: rgba(128, 128, 128, 0.1);"><td style="padding: 4px 8px; font-weight: bold;">CPU %</td><td style="padding: 4px 8px; text-align: center;">95</td><td style="padding: 4px 8px; text-align: center;">95</td><td style="padding: 4px 8px; text-align: center;">95</td><td style="padding: 4px 8px; text-align: center;">95</td><td style="padding: 4px 8px; text-align: center;">94</td><td style="padding: 4px 8px; text-align: center;">94</td><td style="padding: 4px 8px; text-align: center;">94</td><td style="padding: 4px 8px; text-align: center;">94</td><td style="padding: 4px 8px; text-align: center;">93</td><td style="padding: 4px 8px; text-align: center;">93</td></tr></table><div style="margin-top: 6px; font-size: 11px;">Total CPU time: <span style="font-weight: normal; color: #666;">28.61 s</span></div></div></div>
